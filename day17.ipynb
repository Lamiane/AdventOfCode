# %%
def task_1(n_steps=354):
    circular_list = [0]
    current = 0
    for i in range(1,2017):
        border = (current+n_steps) % len(circular_list)
    
        circular_list = circular_list[:(border+1)%len(circular_list)] + [i] + circular_list[(border+1)%len(circular_list):]
        current = (border+1) % len(circular_list)
        print circular_list, current
    return circular_list[(current+1)%len(circular_list)]

# %%
print task_1(3)
# Out:
# [1, 0] 1
# [1, 2, 0] 1
# [1, 2, 3, 0] 2
# [1, 2, 4, 3, 0] 2
# [1, 5, 2, 4, 3, 0] 1
# [1, 5, 2, 4, 3, 6, 0] 5
# [1, 5, 7, 2, 4, 3, 6, 0] 2
# [1, 5, 7, 2, 4, 3, 8, 6, 0] 6
# [1, 9, 5, 7, 2, 4, 3, 8, 6, 0] 1
# [1, 9, 5, 7, 2, 10, 4, 3, 8, 6, 0] 5
# [1, 9, 5, 7, 2, 10, 4, 3, 8, 11, 6, 0] 9
# [1, 12, 9, 5, 7, 2, 10, 4, 3, 8, 11, 6, 0] 1
# [1, 12, 9, 5, 7, 13, 2, 10, 4, 3, 8, 11, 6, 0] 5
# [1, 12, 9, 5, 7, 13, 2, 10, 4, 14, 3, 8, 11, 6, 0] 9
# [1, 12, 9, 5, 7, 13, 2, 10, 4, 14, 3, 8, 11, 15, 6, 0] 13
# [1, 16, 12, 9, 5, 7, 13, 2, 10, 4, 14, 3, 8, 11, 15, 6, 0] 1
# [1, 16, 12, 9, 5, 17, 7, 13, 2, 10, 4, 14, 3, 8, 11, 15, 6, 0] 5
# [1, 16, 12, 9, 5, 17, 7, 13, 2, 18, 10, 4, 14, 3, 8, 11, 15, 6, 0] 9
# [1, 16, 12, 9, 5, 17, 7, 13, 2, 18, 10, 4, 14, 19, 3, 8, 11, 15, 6, 0] 13
# [1, 16, 12, 9, 5, 17, 7, 13, 2, 18, 10, 4, 14, 19, 3, 8, 11, 20, 15, 6, 0] 17
# [21, 1, 16, 12, 9, 5, 17, 7, 13, 2, 18, 10, 4, 14, 19, 3, 8, 11, 20, 15, 6, 0] 21
# ...

# %%
# 1071 is too low

a=[1, 2, 3]
a[:0]
